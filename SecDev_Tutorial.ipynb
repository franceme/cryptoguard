// %% [markdown]
// # SecDev Sampling Tutorial

// %% [markdown]
// ## Native Testing Imports

// %%
// Importing the local CryptoGuard Jar
List <String> addedJars = %jars *.jar
//*/

// Maven Imports
%maven junit:junit:4.12
%maven org.apache.commons:commons-io:1.3.2
%maven commons-io:commons-io:2.7
%maven com.binarytweed:quarantining-test-runner:0.0.3

// Gradle imports
import static org.junit.Assert.assertFalse;
import static org.junit.Assert.assertTrue;
import static org.junit.Assert.assertEquals;
import static org.junit.Assert.assertNull;
import static org.junit.Assert.assertNotNull;
import static util.Utils.makeArg;
import frontEnd.Interface.outputRouting.ExceptionHandler;
import frontEnd.Interface.ArgumentsCheck;
import frontEnd.MessagingSystem.routing.Listing;
import frontEnd.MessagingSystem.routing.EnvironmentInformation;
import frontEnd.MessagingSystem.routing.structure.Default.Report;
import frontEnd.MessagingSystem.routing.structure.Scarf.AnalyzerReport;
import frontEnd.MessagingSystem.routing.structure.Scarf.BugInstance;
import frontEnd.Interface.EntryPoint;
import rule.engine.EngineType;
import frontEnd.argsIdentifier;
import java.io.File;
import java.nio.charset.StandardCharsets;
import java.nio.file.Files;
import java.nio.file.Paths;
import java.util.ArrayList;
import java.util.Arrays;
import java.util.List;
import org.junit.After;
import org.junit.Before;
import org.junit.Test;
import org.junit.runner.RunWith;
import soot.G;
import util.Utils;
import org.apache.commons.io.FileUtils;
import java.util.Scanner;
import org.apache.commons.io.filefilter.WildcardFileFilter;
import com.binarytweed.test.Quarantine;
import com.binarytweed.test.QuarantiningRunner;
import java.io.File;

// %% [markdown]
// ## What version of CryptoGuard is this notebook using?

// %%
System.out.println("Cryptoguard Version: " + Utils.projectVersion);
// Out:
// Warning: Nashorn engine is planned to be removed from a future JDK release
// Cryptoguard Version: 04.05.01

// %% [markdown]
// ## Loading the Custom Java And APK Versions

// %%
String cur_user = System.getProperty("user.name");
String java_home = "/home/" + cur_user + "/.sdkman/candidates/java/8*.0.25*";
String java7_home = "/home/" + cur_user + "/.sdkman/candidates/java/7*";
String android_home = "/home/" + cur_user + "/.sdkman/candidates/android/current";

//Retrieving a specific path from a wild card based list
public static String getFileFromWildCard(String path) {
	String[] split = path.split("/");
	StringBuilder build = new StringBuilder();
	for (int itr = 0;itr < split.length - 1;itr ++)
		build.append(split[itr]).append("/");

	String[] files = new File(build.toString()).list(new WildcardFileFilter(split[split.length-1]));

	if (files.length > 0)
		return build.toString() + files[files.length - 1];
	else
		return null;
}

java_home = getFileFromWildCard(java_home);
java7_home = getFileFromWildCard(java7_home);

public static void print(String file) {
	try {
	Scanner reader = new Scanner(new File(file));

	while (reader.hasNextLine()) System.out.println(reader.nextLine());
	} catch (FileNotFoundException e) {
	}
}

// %% [markdown]
// ## Test Setup

// %%
// region String Statics
public static final Boolean isLinux = !System.getProperty("os.name").contains("Windows");

public static final String basePath = System.getProperty("user.dir");
public static final String testRec = Utils.osPathJoin(basePath, "samples");
public static final String testPath = Utils.osPathJoin(basePath, "tmp");

FileUtils.deleteDirectory(new File (testPath));
new File(testPath).mkdirs();

public long startTime;
public long endTime;

public static void start(){
	startTime = System.currentTimeMillis();
}
public static void end(){
	endTime = System.currentTimeMillis();
	System.out.println("Total Execution time: " + (endTime - startTime) + " ms");
}
public static void create(String path) {
	File newFile = new File(path);
	try{
		newFile.delete();
		newFile.createNewFile();
	} catch(Exception e) {
		
	}
}

// %% [markdown]
// ## APK Setup

// %%
public static final String tempFileOutApk = Utils.osPathJoin(testPath, "app-debug.txt");
public static final String tempFileOutApk_XML = Utils.osPathJoin(testPath, "app-debug.xml");
public static final String tempFileOutApk_JSON = Utils.osPathJoin(testPath, "app-debug.json");
public static final String tempFileOutApk_CSV = Utils.osPathJoin(testPath, "app-debug.csv");

create(tempFileOutApk);
create(tempFileOutApk_XML);
create(tempFileOutApk_JSON);
create(tempFileOutApk_CSV);

public static final String pathToAPK = Utils.osPathJoin(testRec, "app-debug.apk");

// %% [markdown]
// ## APK Tests

// %%
@RunWith(QuarantiningRunner.class)
@Quarantine({"com.binarytweed", "*"})
public class main_TestableApk_Legacy {
	public static void apply() {
	  G.reset();
	  String fileOut = tempFileOutApk;

	  new File(fileOut).delete();
	  if (isLinux) {
		String args =
			makeArg(argsIdentifier.FORMAT, EngineType.APK)
				+ makeArg(argsIdentifier.SOURCE, pathToAPK)
				+ makeArg(argsIdentifier.FORMATOUT, Listing.Legacy)
				+ makeArg(argsIdentifier.ANDROID, android_home)
				+ makeArg(argsIdentifier.JAVA, java_home)
				+ makeArg(argsIdentifier.NOEXIT)
				+ makeArg(argsIdentifier.OUT, fileOut);

		try {
		  EntryPoint.main(args.split(" "));

		  List<String> results = Files.readAllLines(Paths.get(fileOut), StandardCharsets.UTF_8);
		  assertTrue(results.size() >= 10);
		  print(fileOut);
		} catch (Exception e) {
		  e.printStackTrace();
		  assertNull(e);
		}
	  }
	}
}

// %%
start();
main_TestableApk_Legacy.apply();
end();
// Out:
// WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
// Warning: Nashorn engine is planned to be removed from a future JDK release
// Warning: Nashorn engine is planned to be removed from a future JDK release
//  INFO | 2020-09-10 10:58:22.841 | Interface.ArgumentsCheck (ArgumentsCheck.java:150) | Displaying info level logs
//  INFO | 2020-09-10 10:58:22.967 | Interface.ArgumentsCheck (ArgumentsCheck.java:178) | Using the output: Legacy
//  INFO | 2020-09-10 10:58:22.974 | Interface.ArgumentsCheck (ArgumentsCheck.java:343) | Scanning 1 source file(s).
//  INFO | 2020-09-10 10:58:22.986 | routing.EnvironmentInformation (EnvironmentInformation.java:376) | Building the Package Root Dir based on type
//  INFO | 2020-09-10 10:58:22.991 | routing.EnvironmentInformation (EnvironmentInformation.java:410) | Building the Root Directory
//  INFO | 2020-09-10 10:58:22.999 | Interface.SubRunner (SubRunner.java:57) | Starting the scanning process
//  INFO | 2020-09-10 10:58:23.014 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: InsecureAssymCryptoFinder
//  INFO | 2020-09-10 10:58:35.882 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: BrokenCryptoFinder
//  INFO | 2020-09-10 10:58:36.443 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: UntrustedPrngFinder
//  INFO | 2020-09-10 10:58:36.473 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: SSLSocketFactoryFinder
//  INFO | 2020-09-10 10:58:36.550 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: CustomTrustManagerFinder
//  INFO | 2020-09-10 10:58:36.576 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: HostNameVerifierFinder
//  INFO | 2020-09-10 10:58:36.601 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: BrokenHashFinder
//  INFO | 2020-09-10 10:58:36.847 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: ConstantKeyFinder
//  INFO | 2020-09-10 10:58:37.515 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableIVFinder
//  INFO | 2020-09-10 10:58:37.704 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PBESaltFinder
//  INFO | 2020-09-10 10:58:38.278 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PBEInterationCountFinder
//  INFO | 2020-09-10 10:58:38.677 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableSeedFinder
//  INFO | 2020-09-10 10:58:38.787 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableKeyStorePasswordFinder
//  INFO | 2020-09-10 10:58:38.925 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: HttpUrlFinder
//  INFO | 2020-09-10 10:58:39.176 | Interface.SubRunner (SubRunner.java:59) | Stopped the scanning process
//  INFO | 2020-09-10 10:58:39.180 | Interface.SubRunner (SubRunner.java:62) | Writing the output to the file: /home/maister/Projects/cryptoguard/tmp/app-debug.txt
// /home/maister/Projects/cryptoguard/tmp/app-debug.txt
// Analyzing APK File: /home/maister/Projects/cryptoguard/samples/app-debug.apk
// =======================================
// ***Violated Rule 1: Found broken crypto schemes
// ***Found: "PBEWithMD5AndDES" in org.rigorityj.android_sample.crypto.PasswordUtils::init.
// =======================================
// =======================================
// ***Violated Rule 2: Found broken hash functions
// ***Found: "SHA1" in org.rigorityj.android_sample.crypto.VeryBadMain::main.
// ***Found: "MD5" in org.rigorityj.android_sample.crypto.VeryBadMain::main.
// =======================================
// =======================================
// ***Violated Rule 3: Used constant keys in code
// ***Found: Constant "my+secret+key+lol" in org.rigorityj.android_sample.crypto.VeryBadMain::main.
// ***Found: Constant "tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV" in org.rigorityj.android_sample.crypto.PasswordUtils::init:78.
// ***Found: Constant "RandomInitVector" in org.rigorityj.android_sample.crypto.VeryBadMain::main.
// =======================================
// =======================================
// ***Violated Rule 4: Uses untrusted TrustManager
// ***Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of crypto.BadCertificateValidation in crypto.BadCertificateValidation::getAcceptedIssuers.
// ***Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of crypto.BadCertificateValidation in crypto.BadCertificateValidation::getAcceptedIssuers.
// ***Should throw java.security.cert.CertificateException in check(Client|Server)Trusted method of crypto.BadCertificateValidation in crypto.BadCertificateValidation::UNKNOWN.
// =======================================
// =======================================
// ***Violated Rule 5: Used export grade public Key
// ***Cause: Used default key size in org.rigorityj.android_sample.crypto.BadAssymCrypto::generateKeyPairImplicit:12.
// ***Found: "512" in org.rigorityj.android_sample.crypto.VeryBadMain::main.
// =======================================
// =======================================
// ***Violated Rule 6: Used untrusted HostNameVerifier
// ***Cause: Fixed "[1]" in crypto.BadHostnameVerification::UNKNOWN.
// =======================================
// =======================================
// ***Violated Rule 8: Used < 1000 iteration for PBE
// ***Found: "17" in org.rigorityj.android_sample.crypto.PasswordUtils::init.
// =======================================
// =======================================
// ***Violated Rule 9: Found constant salts in code
// ***Found: "tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV" in org.rigorityj.android_sample.crypto.PasswordUtils::init:78.
// ***Found: "f77aLYLo" in org.rigorityj.android_sample.crypto.PasswordUtils::init:79.
// =======================================
// =======================================
// ***Violated Rule 10: Found constant IV in code
// ***Found: "RandomInitVector" in org.rigorityj.android_sample.crypto.VeryBadMain::main.
// =======================================
// =======================================
// ***Violated Rule 12: Should check HostnameVerification manually
// ***Didn't manually verify hostname in writeToBadSocket in org.rigorityj.android_sample.crypto.BadHostnameVerification::writeToBadSocket.
// =======================================
// =======================================
// ***Violated Rule 13: Used untrusted PRNG
// ***Found: Untrused PRNG (java.util.Random) in org.rigorityj.android_sample.crypto.BadDigestAndRandom::generateRandomBytes.
// =======================================
// Total Execution time: 16682 ms

// %%
@RunWith(QuarantiningRunner.class)
@Quarantine({"com.binarytweed", "*"})
public class main_TestableApk_XML {
	public static void apply() {
	  G.reset();
	  String fileOut = tempFileOutApk_XML;

	  new File(fileOut).delete();
	  if (isLinux) {
		String args =
			makeArg(argsIdentifier.FORMAT, EngineType.APK)
				+ makeArg(argsIdentifier.SOURCE, pathToAPK)
				+ makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML)
				+ makeArg(argsIdentifier.ANDROID, android_home)
				+ makeArg(argsIdentifier.JAVA, java_home)
				+ makeArg(argsIdentifier.NOEXIT)
				+ makeArg(argsIdentifier.OUT, fileOut);

		try {
		  EntryPoint.main(args.split(" "));
		  print(fileOut);
		} catch (Exception e) {
		  e.printStackTrace();
		  assertNull(e);
		}
	  }
	}
}

// %%
start();
main_TestableApk_XML.apply();
end();
// Out:
//  INFO | 2020-09-10 10:58:39.445 | Interface.ArgumentsCheck (ArgumentsCheck.java:150) | Displaying info level logs
//  INFO | 2020-09-10 10:58:39.448 | Interface.ArgumentsCheck (ArgumentsCheck.java:178) | Using the output: ScarfXML
//  INFO | 2020-09-10 10:58:39.450 | Interface.ArgumentsCheck (ArgumentsCheck.java:343) | Scanning 1 source file(s).
//  INFO | 2020-09-10 10:58:39.453 | routing.EnvironmentInformation (EnvironmentInformation.java:376) | Building the Package Root Dir based on type
//  INFO | 2020-09-10 10:58:39.456 | routing.EnvironmentInformation (EnvironmentInformation.java:410) | Building the Root Directory
//  INFO | 2020-09-10 10:58:39.460 | Interface.SubRunner (SubRunner.java:57) | Starting the scanning process
//  INFO | 2020-09-10 10:58:39.463 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: InsecureAssymCryptoFinder
//  INFO | 2020-09-10 10:58:51.139 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: BrokenCryptoFinder
//  INFO | 2020-09-10 10:58:51.676 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: UntrustedPrngFinder
//  INFO | 2020-09-10 10:58:51.704 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: SSLSocketFactoryFinder
//  INFO | 2020-09-10 10:58:51.772 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: CustomTrustManagerFinder
//  INFO | 2020-09-10 10:58:51.797 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: HostNameVerifierFinder
//  INFO | 2020-09-10 10:58:51.819 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: BrokenHashFinder
//  INFO | 2020-09-10 10:58:52.067 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: ConstantKeyFinder
//  INFO | 2020-09-10 10:58:52.668 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableIVFinder
//  INFO | 2020-09-10 10:58:52.859 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PBESaltFinder
//  INFO | 2020-09-10 10:58:53.374 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PBEInterationCountFinder
//  INFO | 2020-09-10 10:58:53.838 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableSeedFinder
//  INFO | 2020-09-10 10:58:53.944 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableKeyStorePasswordFinder
//  INFO | 2020-09-10 10:58:54.077 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: HttpUrlFinder
//  INFO | 2020-09-10 10:58:54.342 | Interface.SubRunner (SubRunner.java:59) | Stopped the scanning process
//  INFO | 2020-09-10 10:58:54.344 | block.ScarfXML (ScarfXML.java:69) | Marshalling the AnalyzerReport from the Env. Info.
//  INFO | 2020-09-10 10:58:54.352 | block.ScarfXML (ScarfXML.java:89) | Marshalling the bug category summary.
//  INFO | 2020-09-10 10:58:54.456 | Interface.SubRunner (SubRunner.java:62) | Writing the output to the file: /home/maister/Projects/cryptoguard/tmp/app-debug.xml
// /home/maister/Projects/cryptoguard/tmp/app-debug.xml
// <AnalyzerReport assessment_start_ts="2020-09-10_10:58:39" package_name="app-debug" package_version="UNKNOWN" build_root_dir="/home/maister/Projects/cryptoguard/app-debug.apk" package_root_dir="app-debug.apk/" parser_fw="UNKNOWN" parser_fw_version="UNKNOWN" platform_name="Linux_5.4.0-47-generic" tool_name="Property Not Found" tool_version="Property Not Found" uuid="38f618a0-dabd-4553-bc09-d19e82d948da"><BugInstance id="0"><ClassName>org.rigorityj.android_sample.crypto.BadAssymCrypto</ClassName><Methods><Method id="0" primary="true">generateKeyPairImplicit</Method></Methods><BugLocations><Location><SourceFile>app-debug.apk/org/rigorityj/android_sample/crypto/BadAssymCrypto.class</SourceFile><StartLine>12</StartLine></Location></BugLocations><CweId>321</CweId><BugCode>ExportGradePubKey</BugCode><BugMessage>Cause: Used default key size. Used export grade public Key.</BugMessage></BugInstance><BugInstance id="1"><ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName><Methods><Method id="0" primary="true">main</Method></Methods><BugLocations><Location><SourceFile>app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile></Location></BugLocations><CweId>321</CweId><BugCode>ExportGradePubKey</BugCode><BugMessage>Found: "512". Used export grade public Key.</BugMessage></BugInstance><BugInstance id="2"><ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName><Methods><Method id="0" primary="true">init</Method></Methods><BugLocations><Location><SourceFile>app-debug.apk/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile></Location></BugLocations><CweId>256</CweId><BugCode>BrokenCrypto</BugCode><BugMessage>Found: "PBEWithMD5AndDES". Found broken crypto schemes.</BugMessage></BugInstance><BugInstance id="3"><ClassName>org.rigorityj.android_sample.crypto.BadDigestAndRandom</ClassName><Methods><Method id="0" primary="true">generateRandomBytes</Method></Methods><BugLocations><Location><SourceFile>app-debug.apk/org/rigorityj/android_sample/crypto/BadDigestAndRandom.class</SourceFile></Location></BugLocations><CweId>338</CweId><BugCode>UntrustedPRNG</BugCode><BugMessage>Found: Untrused PRNG (java.util.Random). Used untrusted PRNG.</BugMessage></BugInstance><BugInstance id="4"><ClassName>org.rigorityj.android_sample.crypto.BadHostnameVerification</ClassName><Methods><Method id="0" primary="true">writeToBadSocket</Method></Methods><BugLocations><Location><SourceFile>app-debug.apk/org/rigorityj/android_sample/crypto/BadHostnameVerification.class</SourceFile></Location></BugLocations><CweId>297</CweId><BugCode>CheckHostname</BugCode><BugMessage>Didn't manually verify hostname in writeToBadSocket. Should check HostnameVerification manually.</BugMessage></BugInstance><BugInstance id="5"><ClassName>crypto.BadCertificateValidation</ClassName><Methods><Method id="0" primary="true">getAcceptedIssuers</Method></Methods><BugLocations><Location><SourceFile>app-debug.apk/crypto/BadCertificateValidation.class</SourceFile></Location></BugLocations><CweId>349</CweId><BugCode>UntrustedTrustMgr</BugCode><BugMessage>Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of crypto.BadCertificateValidation. Uses untrusted TrustManager.</BugMessage></BugInstance><BugInstance id="6"><ClassName>crypto.BadCertificateValidation</ClassName><Methods><Method id="0" primary="true">getAcceptedIssuers</Method></Methods><BugLocations><Location><SourceFile>app-debug.apk/crypto/BadCertificateValidation.class</SourceFile></Location></BugLocations><CweId>349</CweId><BugCode>UntrustedTrustMgr</BugCode><BugMessage>Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of crypto.BadCertificateValidation. Uses untrusted TrustManager.</BugMessage></BugInstance><BugInstance id="7"><ClassName>crypto.BadCertificateValidation</ClassName><Methods><Method id="0" primary="true">UNKNOWN</Method></Methods><BugLocations><Location><SourceFile>app-debug.apk/crypto/Ba ...
// Total Execution time: 15070 ms

// %%
@RunWith(QuarantiningRunner.class)
@Quarantine({"com.binarytweed", "*"})
public class main_TestableApk_JSON {
	public static void apply() {
	  G.reset();
	  String fileOut = tempFileOutApk_JSON;

	  new File(fileOut).delete();
	  if (isLinux) {
		String args =
			makeArg(argsIdentifier.FORMAT, EngineType.APK)
				+ makeArg(argsIdentifier.SOURCE, pathToAPK)
				+ makeArg(argsIdentifier.ANDROID, android_home)
				+ makeArg(argsIdentifier.JAVA, java_home)
				+ makeArg(argsIdentifier.NOEXIT)
				+ makeArg(argsIdentifier.OUT, fileOut);

		try {
		  EntryPoint.main(args.split(" "));
		  print(fileOut);
		} catch (Exception e) {
		  e.printStackTrace();
		  assertNull(e);
		}
	  }
	}
}

// %%
start();
main_TestableApk_JSON.apply();
end();
// Out:
//  INFO | 2020-09-10 10:58:54.685 | Interface.ArgumentsCheck (ArgumentsCheck.java:150) | Displaying info level logs
//  INFO | 2020-09-10 10:58:54.687 | Interface.ArgumentsCheck (ArgumentsCheck.java:178) | Using the output: Default
//  INFO | 2020-09-10 10:58:54.690 | Interface.ArgumentsCheck (ArgumentsCheck.java:343) | Scanning 1 source file(s).
//  INFO | 2020-09-10 10:58:54.692 | routing.EnvironmentInformation (EnvironmentInformation.java:376) | Building the Package Root Dir based on type
//  INFO | 2020-09-10 10:58:54.694 | routing.EnvironmentInformation (EnvironmentInformation.java:410) | Building the Root Directory
//  INFO | 2020-09-10 10:58:54.698 | Interface.SubRunner (SubRunner.java:57) | Starting the scanning process
//  INFO | 2020-09-10 10:58:54.700 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: InsecureAssymCryptoFinder
//  INFO | 2020-09-10 10:59:06.099 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: BrokenCryptoFinder
//  INFO | 2020-09-10 10:59:06.621 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: UntrustedPrngFinder
//  INFO | 2020-09-10 10:59:06.646 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: SSLSocketFactoryFinder
//  INFO | 2020-09-10 10:59:06.711 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: CustomTrustManagerFinder
//  INFO | 2020-09-10 10:59:06.733 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: HostNameVerifierFinder
//  INFO | 2020-09-10 10:59:06.755 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: BrokenHashFinder
//  INFO | 2020-09-10 10:59:06.980 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: ConstantKeyFinder
//  INFO | 2020-09-10 10:59:07.705 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableIVFinder
//  INFO | 2020-09-10 10:59:07.945 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PBESaltFinder
//  INFO | 2020-09-10 10:59:08.614 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PBEInterationCountFinder
//  INFO | 2020-09-10 10:59:09.146 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableSeedFinder
//  INFO | 2020-09-10 10:59:09.274 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableKeyStorePasswordFinder
//  INFO | 2020-09-10 10:59:09.425 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: HttpUrlFinder
//  INFO | 2020-09-10 10:59:09.715 | Interface.SubRunner (SubRunner.java:59) | Stopped the scanning process
//  INFO | 2020-09-10 10:59:09.717 | block.Default (Default.java:68) | Marshalling the Report from the Env. Info.
//  INFO | 2020-09-10 10:59:09.743 | Interface.SubRunner (SubRunner.java:62) | Writing the output to the file: /home/maister/Projects/cryptoguard/tmp/app-debug.json
// /home/maister/Projects/cryptoguard/tmp/app-debug.json
// {"projectName":"CryptoGuard","ProjectVersion":"04.05.01","Target":{"RawCommand":"-in apk -s /home/maister/Projects/cryptoguard/samples/app-debug.apk -android /home/maister/.sdkman/candidates/android/current -java /home/maister/.sdkman/candidates/java/8.0.252.hs-adpt -X -o /home/maister/Projects/cryptoguard/tmp/app-debug.json","FullPath":"app-debug.apk/","Type":"APK","TargetSources":["/home/maister/Projects/cryptoguard/samples/app-debug.apk"],"_PropertiesFilePath":"gradle.properties","_ComputerOS":"Linux_5.4.0-47-generic","_JVMVersion":"11.0.7+10","_ProjectName":"app-debug"},"Issues":[{"Message":"Cause: Used default key size","Description":"Used export grade public Key","RuleNumber":5,"RuleDesc":"Used export grade public Key","CWEId":321,"Severity":"1","_FullPath":"app-debug.apk/org/rigorityj/android_sample/crypto/BadAssymCrypto.class","_Id":"0"},{"Message":"Found: \"512\"","Description":"Used export grade public Key","RuleNumber":5,"RuleDesc":"Used export grade public Key","CWEId":321,"Severity":"1","_FullPath":"app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"1"},{"Message":"Found: \"PBEWithMD5AndDES\"","Description":"Found broken crypto schemes","RuleNumber":1,"RuleDesc":"Found broken crypto schemes","CWEId":256,"Severity":"1","_FullPath":"app-debug.apk/org/rigorityj/android_sample/crypto/PasswordUtils.class","_Id":"2"},{"Message":"Found: Untrused PRNG (java.util.Random)","Description":"Used untrusted PRNG","RuleNumber":13,"RuleDesc":"Used untrusted PRNG","CWEId":338,"Severity":"1","_FullPath":"app-debug.apk/org/rigorityj/android_sample/crypto/BadDigestAndRandom.class","_Id":"3"},{"Message":"Didn't manually verify hostname in writeToBadSocket","Description":"Should check HostnameVerification manually","RuleNumber":12,"RuleDesc":"Should check HostnameVerification manually","CWEId":297,"Severity":"1","_FullPath":"app-debug.apk/org/rigorityj/android_sample/crypto/BadHostnameVerification.class","_Id":"4"},{"Message":"Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of crypto.BadCertificateValidation","Description":"Uses untrusted TrustManager","RuleNumber":4,"RuleDesc":"Uses untrusted TrustManager","CWEId":349,"Severity":"1","_FullPath":"app-debug.apk/crypto/BadCertificateValidation.class","_Id":"5"},{"Message":"Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of crypto.BadCertificateValidation","Description":"Uses untrusted TrustManager","RuleNumber":4,"RuleDesc":"Uses untrusted TrustManager","CWEId":349,"Severity":"1","_FullPath":"app-debug.apk/crypto/BadCertificateValidation.class","_Id":"6"},{"Message":"Should throw java.security.cert.CertificateException in check(Client|Server)Trusted method of crypto.BadCertificateValidation","Description":"Uses untrusted TrustManager","RuleNumber":4,"RuleDesc":"Uses untrusted TrustManager","CWEId":349,"Severity":"1","_FullPath":"app-debug.apk/crypto/BadCertificateValidation.class","_Id":"7"},{"Message":"Cause: Fixed \"[1]\"","Description":"Used untrusted HostNameVerifier","RuleNumber":6,"RuleDesc":"Used untrusted HostNameVerifier","CWEId":601,"Severity":"1","_FullPath":"app-debug.apk/crypto/BadHostnameVerification.class","_Id":"8"},{"Message":"Found: \"SHA1\"","Description":"Found broken hash functions","RuleNumber":2,"RuleDesc":"Found broken hash functions","CWEId":759,"Severity":"1","_FullPath":"app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"9"},{"Message":"Found: \"MD5\"","Description":"Found broken hash functions","RuleNumber":2,"RuleDesc":"Found broken hash functions","CWEId":759,"Severity":"1","_FullPath":"app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"10"},{"Message":"Found: Constant \"my+secret+key+lol\"","Description":"Used constant keys in code","RuleNumber":3,"RuleDesc":"Used constant keys in code","CWEId":547,"Severity":"1","_FullPath":"app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"11"}, ...
// Total Execution time: 15120 ms

// %%
@RunWith(QuarantiningRunner.class)
@Quarantine({"com.binarytweed", "*"})
public class main_TestableApk_CSV {
	public static void apply() {
	  G.reset();
	  String fileOut = tempFileOutApk_CSV;

	  new File(fileOut).delete();
	  if (isLinux) {
		String args =
			makeArg(argsIdentifier.FORMAT, EngineType.APK)
				+ makeArg(argsIdentifier.SOURCE, pathToAPK)
				+ makeArg(argsIdentifier.FORMATOUT, Listing.CSVDefault)
				+ makeArg(argsIdentifier.ANDROID, android_home)
				+ makeArg(argsIdentifier.JAVA, java_home)
				+ makeArg(argsIdentifier.NOEXIT)
				+ makeArg(argsIdentifier.OUT, fileOut);

		try {
		  EntryPoint.main(args.split(" "));
		  print(fileOut);
		} catch (Exception e) {
		  e.printStackTrace();
		  assertNull(e);
		}
	  }
	}
}

// %%
start();
main_TestableApk_CSV.apply();
end();
// Out:
//  INFO | 2020-09-10 10:59:09.952 | Interface.ArgumentsCheck (ArgumentsCheck.java:150) | Displaying info level logs
//  INFO | 2020-09-10 10:59:09.954 | Interface.ArgumentsCheck (ArgumentsCheck.java:178) | Using the output: CSVDefault
//  INFO | 2020-09-10 10:59:09.956 | Interface.ArgumentsCheck (ArgumentsCheck.java:343) | Scanning 1 source file(s).
//  INFO | 2020-09-10 10:59:09.959 | routing.EnvironmentInformation (EnvironmentInformation.java:376) | Building the Package Root Dir based on type
//  INFO | 2020-09-10 10:59:09.961 | routing.EnvironmentInformation (EnvironmentInformation.java:410) | Building the Root Directory
//  INFO | 2020-09-10 10:59:09.965 | Interface.SubRunner (SubRunner.java:57) | Starting the scanning process
//  INFO | 2020-09-10 10:59:09.967 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: InsecureAssymCryptoFinder
//  INFO | 2020-09-10 10:59:21.487 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: BrokenCryptoFinder
//  INFO | 2020-09-10 10:59:22.037 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: UntrustedPrngFinder
//  INFO | 2020-09-10 10:59:22.067 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: SSLSocketFactoryFinder
//  INFO | 2020-09-10 10:59:22.147 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: CustomTrustManagerFinder
//  INFO | 2020-09-10 10:59:22.172 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: HostNameVerifierFinder
//  INFO | 2020-09-10 10:59:22.196 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: BrokenHashFinder
//  INFO | 2020-09-10 10:59:22.436 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: ConstantKeyFinder
//  INFO | 2020-09-10 10:59:23.113 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableIVFinder
//  INFO | 2020-09-10 10:59:23.331 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PBESaltFinder
//  INFO | 2020-09-10 10:59:23.924 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PBEInterationCountFinder
//  INFO | 2020-09-10 10:59:24.423 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableSeedFinder
//  INFO | 2020-09-10 10:59:24.552 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: PredictableKeyStorePasswordFinder
//  INFO | 2020-09-10 10:59:24.710 | engine.ApkEntry (ApkEntry.java:24) | Checking the rule: HttpUrlFinder
//  INFO | 2020-09-10 10:59:24.979 | Interface.SubRunner (SubRunner.java:59) | Stopped the scanning process
//  INFO | 2020-09-10 10:59:24.981 | block.CSVDefault (CSVDefault.java:72) | Marshalling the Report from the Env. Info.
//  INFO | 2020-09-10 10:59:24.992 | Interface.SubRunner (SubRunner.java:62) | Writing the output to the file: /home/maister/Projects/cryptoguard/tmp/app-debug.csv
// /home/maister/Projects/cryptoguard/tmp/app-debug.csv
// ProjectName,ProjectVersion,FullPath,ComputerOs,JVMVersion,IssueId,IssueMessage,IssueDescription,IssueRuleNumber,IssueRuleDescription,CWEId,IssueSeverity,IssueFullPath
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,0,Cause: Used default key size,Used export grade public Key,5,Used export grade public Key,321,1,app-debug.apk/org/rigorityj/android_sample/crypto/BadAssymCrypto.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,1,Found: "512",Used export grade public Key,5,Used export grade public Key,321,1,app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,2,Found: "PBEWithMD5AndDES",Found broken crypto schemes,1,Found broken crypto schemes,256,1,app-debug.apk/org/rigorityj/android_sample/crypto/PasswordUtils.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,3,Found: Untrused PRNG (java.util.Random),Used untrusted PRNG,13,Used untrusted PRNG,338,1,app-debug.apk/org/rigorityj/android_sample/crypto/BadDigestAndRandom.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,4,Didn't manually verify hostname in writeToBadSocket,Should check HostnameVerification manually,12,Should check HostnameVerification manually,297,1,app-debug.apk/org/rigorityj/android_sample/crypto/BadHostnameVerification.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,5,Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of crypto.BadCertificateValidation,Uses untrusted TrustManager,4,Uses untrusted TrustManager,349,1,app-debug.apk/crypto/BadCertificateValidation.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,6,Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of crypto.BadCertificateValidation,Uses untrusted TrustManager,4,Uses untrusted TrustManager,349,1,app-debug.apk/crypto/BadCertificateValidation.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,7,Should throw java.security.cert.CertificateException in check(Client|Server)Trusted method of crypto.BadCertificateValidation,Uses untrusted TrustManager,4,Uses untrusted TrustManager,349,1,app-debug.apk/crypto/BadCertificateValidation.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,8,Cause: Fixed "[1]",Used untrusted HostNameVerifier,6,Used untrusted HostNameVerifier,601,1,app-debug.apk/crypto/BadHostnameVerification.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,9,Found: "SHA1",Found broken hash functions,2,Found broken hash functions,759,1,app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,10,Found: "MD5",Found broken hash functions,2,Found broken hash functions,759,1,app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,11,Found: Constant "my+secret+key+lol",Used constant keys in code,3,Used constant keys in code,547,1,app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,12,Found: Constant "tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV",Used constant keys in code,3,Used constant keys in code,547,1,app-debug.apk/org/rigorityj/android_sample/crypto/PasswordUtils.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,13,Found: Constant "RandomInitVector",Used constant keys in code,3,Used constant keys in code,547,1,app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,14,Found: "RandomInitVector",Found constant IV in code,10,Found constant IV in code,547,1,app-debug.apk/org/rigorityj/android_sample/crypto/VeryBadMain.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,15,Found: "tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV",Found constant salts in code,9,Found constant salts in code,547,1,app-debug.apk/org/rigorityj/android_sample/crypto/PasswordUtils.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,16,Found: "f77aLYLo",Found constant salts in code,9,Found constant salts in code,547,1,app-debug.apk/org/rigorityj/android_sample/crypto/PasswordUtils.class
// null,null,/home/maister/Projects/cryptoguard/app-debug.apk,Linux_5.4.0-47-generic,11.0.7+10,17,Found: "17",Used < 1000 iteration for PBE,8,Used < 1000 iteration for PBE,326,1,app-debug.apk/org/rigorityj/android_sample/crypto/PasswordUtils.class
// Total Execution time: 15093 ms

// %% [markdown]
// ## Java Class File Setup

// %%
public static final String verySimple_Klass_xml_1 = Utils.osPathJoin(testPath, "verySimple_klass_1.xml");
public static final String verySimple_Klass_yaml_1 = Utils.osPathJoin(testPath, "verySimple_klass_2.yaml");

create(verySimple_Klass_xml_1);
create(verySimple_Klass_yaml_1);

public static final String verySimple_Path = Utils.osPathJoin(testRec, "VerySimple");
public static final String verySimple_Klass = Utils.osPathJoin(verySimple_Path, "very.class");

// %% [markdown]
// ## Java Class Tests

// %%
@RunWith(QuarantiningRunner.class)
@Quarantine({"com.binarytweed", "*"})
public class main_TestableFile_VerySimple {
	public static void apply() {
	  G.reset();
  soot.G.v().reset();

  String source = verySimple_Klass;
  String fileOut = verySimple_Klass_xml_1;

  new File(fileOut).delete();
  if (isLinux) {
    String args =
        makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES)
            + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML)
            + makeArg(argsIdentifier.SOURCE, source)
            + makeArg(argsIdentifier.NOEXIT)
            + makeArg(argsIdentifier.ANDROID, "/InvalidPath/")
            + makeArg(argsIdentifier.VERYVERBOSE)
            + makeArg(argsIdentifier.STREAM)
            + makeArg(argsIdentifier.PRETTY)
            + makeArg(argsIdentifier.JAVA, java_home)
            + makeArg(argsIdentifier.OUT, fileOut);

    try {
      EntryPoint.main(args.split(" "));
      print(fileOut);
    } catch (Exception e) {
      e.printStackTrace();
      assertNull(e);
    }
  }
	}
}

// %%
start();
main_TestableFile_VerySimple.apply();
end();
// Out:
//  INFO | 2020-09-10 10:59:25.374 | Interface.ArgumentsCheck (ArgumentsCheck.java:142) | Displaying debug level logs
//  INFO | 2020-09-10 10:59:25.375 | Interface.ArgumentsCheck (ArgumentsCheck.java:178) | Using the output: ScarfXML
//  INFO | 2020-09-10 10:59:25.379 | Interface.ArgumentsCheck (ArgumentsCheck.java:343) | Scanning 1 source file(s).
//  INFO | 2020-09-10 10:59:25.381 | routing.EnvironmentInformation (EnvironmentInformation.java:376) | Building the Package Root Dir based on type
//  INFO | 2020-09-10 10:59:25.383 | routing.EnvironmentInformation (EnvironmentInformation.java:410) | Building the Root Directory
//  INFO | 2020-09-10 10:59:25.387 | stream.ScarfXML (ScarfXML.java:74) | Marshalling the header.
//  INFO | 2020-09-10 10:59:25.391 | Interface.SubRunner (SubRunner.java:57) | Starting the scanning process
//  INFO | 2020-09-10 10:59:25.393 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: InsecureAssymCryptoFinder
//  INFO | 2020-09-10 10:59:35.691 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: BrokenCryptoFinder
//  INFO | 2020-09-10 10:59:36.136 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: UntrustedPrngFinder
//  INFO | 2020-09-10 10:59:36.138 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: SSLSocketFactoryFinder
//  INFO | 2020-09-10 10:59:36.141 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: CustomTrustManagerFinder
//  INFO | 2020-09-10 10:59:36.143 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: HostNameVerifierFinder
//  INFO | 2020-09-10 10:59:36.145 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: BrokenHashFinder
//  INFO | 2020-09-10 10:59:36.281 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: ConstantKeyFinder
//  INFO | 2020-09-10 10:59:36.872 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PredictableIVFinder
//  INFO | 2020-09-10 10:59:37.007 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PBESaltFinder
//  INFO | 2020-09-10 10:59:37.484 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PBEInterationCountFinder
//  INFO | 2020-09-10 10:59:37.820 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PredictableSeedFinder
//  INFO | 2020-09-10 10:59:37.839 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PredictableKeyStorePasswordFinder
//  INFO | 2020-09-10 10:59:37.860 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: HttpUrlFinder
//  INFO | 2020-09-10 10:59:38.000 | Interface.SubRunner (SubRunner.java:59) | Stopped the scanning process
//  INFO | 2020-09-10 10:59:38.002 | stream.ScarfXML (ScarfXML.java:113) | Marshalling the bug category summary.
//  INFO | 2020-09-10 10:59:38.007 | Interface.SubRunner (SubRunner.java:62) | Writing the output to the file: /home/maister/Projects/cryptoguard/tmp/verySimple_klass_1.xml
// /home/maister/Projects/cryptoguard/tmp/verySimple_klass_1.xml
// <AnalyzerReport assessment_start_ts="2020-09-10_10:59:25" package_version="UNKNOWN" package_root_dir="~/Projects/cryptoguard/UNKNOWN" parser_fw="UNKNOWN" parser_fw_version="UNKNOWN" platform_name="Linux_5.4.0-47-generic" tool_name="Property Not Found" tool_version="Property Not Found" uuid="3f6efca8-1bfb-4207-b395-d28f24c8ecfe"><BugInstance id="0">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>256</CweId>
//   <BugCode>BrokenCrypto</BugCode>
//   <BugMessage>Found: "PBEWithMD5AndDES". Found broken crypto schemes.</BugMessage>
// </BugInstance>
// <BugInstance id="1">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>759</CweId>
//   <BugCode>BrokenHash</BugCode>
//   <BugMessage>Found: "SHA1". Found broken hash functions.</BugMessage>
// </BugInstance>
// <BugInstance id="2">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>759</CweId>
//   <BugCode>BrokenHash</BugCode>
//   <BugMessage>Found: "MD5". Found broken hash functions.</BugMessage>
// </BugInstance>
// <BugInstance id="3">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantKey</BugCode>
//   <BugMessage>Found: Constant "my+secret+key+lol". Used constant keys in code.</BugMessage>
// </BugInstance>
// <BugInstance id="4">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//       <StartLine>78</StartLine>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantKey</BugCode>
//   <BugMessage>Found: Constant "tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV". Used constant keys in code.</BugMessage>
// </BugInstance>
// <BugInstance id="5">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantKey</BugCode>
//   <BugMessage>Found: Constant "RandomInitVector". Used constant keys in code.</BugMessage>
// </BugInstance>
// <BugInstance id="6">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantIV</BugCode>
//   <BugMessage>Found: "RandomInitVector". Found constant IV in code.</BugMessage>
// </BugInstance>
// <BugInstance id="7">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//       <StartLine>78</StartLine>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantSalt</BugCode>
//   <BugMessage>Found: "tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV". Found constant salts in code.</BugMessage>
// </BugInstance>
// <BugInstance id="8">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//       <StartLine>79</StartLine>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantSalt</BugCode>
//   <BugMessage>Found: "f77aLYLo". Found constant salts in code.</BugMessage>
// </BugInstance>
// <BugInstance id="9">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>326</CweId>
//   <BugCode>PBE</BugCode>
//   <BugMessage>Found: "17". Used &lt; 1000 iteration for PBE.</BugMessage>
// </BugInstance>
// <BugSummary>
//   <BugCategory group="Found broken crypto schemes" code="1" count="1" bytes="0"/>
//   <BugCategory group="Found broken hash functions" code="2" count="2" bytes="0"/>
//   <BugCategory group="Used constant keys in code" code="3" count="3" bytes="0"/>
//   <BugCategory group="Used &lt; 1000 iteration for PBE" code="8" count="1" bytes="0"/>
//   <BugCategory group="Found constant salts in code" code="9" count="2" bytes="0"/>
//   <BugCategory group="Found constant IV in code" code="10" count="1" bytes="0"/>
// </BugSummary>
// </AnalyzerReport>
// Total Execution time: 12732 ms

// %%
@RunWith(QuarantiningRunner.class)
@Quarantine({"com.binarytweed", "*"})
public class main_TestableFile_VerySimple_YAML {
	public static void apply() {
	  G.reset();
  soot.G.v().reset();

  String source = verySimple_Klass;
  String fileOut = verySimple_Klass_yaml_1;
  Listing type = Listing.YAMLGeneric;

  new File(fileOut).delete();
  if (isLinux) {
    String args =
        makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES)
            + makeArg(argsIdentifier.FORMATOUT, type)
            + makeArg(argsIdentifier.SOURCE, source)
            + makeArg(argsIdentifier.NOEXIT)
            + makeArg(argsIdentifier.ANDROID, "/InvalidPath/")
            + makeArg(argsIdentifier.VERYVERBOSE)
            +
            // makeArg(argsIdentifier.STREAM)
            makeArg(argsIdentifier.PRETTY)
            + makeArg(argsIdentifier.JAVA, java_home)
            + makeArg(argsIdentifier.OUT, fileOut);

    try {
      EntryPoint.main(args.split(" "));
      print(fileOut);
    } catch (Exception e) {
      e.printStackTrace();
      assertNull(e);
    }
  }
	}
}

// %%
start();
main_TestableFile_VerySimple_YAML.apply();
end();
// Out:
//  INFO | 2020-09-10 10:59:38.277 | Interface.ArgumentsCheck (ArgumentsCheck.java:142) | Displaying debug level logs
//  INFO | 2020-09-10 10:59:38.298 | Interface.ArgumentsCheck (ArgumentsCheck.java:178) | Using the output: Default
//  INFO | 2020-09-10 10:59:38.301 | Interface.ArgumentsCheck (ArgumentsCheck.java:343) | Scanning 1 source file(s).
//  INFO | 2020-09-10 10:59:38.303 | routing.EnvironmentInformation (EnvironmentInformation.java:376) | Building the Package Root Dir based on type
//  INFO | 2020-09-10 10:59:38.306 | routing.EnvironmentInformation (EnvironmentInformation.java:410) | Building the Root Directory
//  INFO | 2020-09-10 10:59:38.308 | Interface.SubRunner (SubRunner.java:57) | Starting the scanning process
//  INFO | 2020-09-10 10:59:38.310 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: InsecureAssymCryptoFinder
//  INFO | 2020-09-10 10:59:48.923 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: BrokenCryptoFinder
//  INFO | 2020-09-10 10:59:49.377 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: UntrustedPrngFinder
//  INFO | 2020-09-10 10:59:49.382 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: SSLSocketFactoryFinder
//  INFO | 2020-09-10 10:59:49.386 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: CustomTrustManagerFinder
//  INFO | 2020-09-10 10:59:49.389 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: HostNameVerifierFinder
//  INFO | 2020-09-10 10:59:49.392 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: BrokenHashFinder
//  INFO | 2020-09-10 10:59:49.534 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: ConstantKeyFinder
//  INFO | 2020-09-10 10:59:50.063 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PredictableIVFinder
//  INFO | 2020-09-10 10:59:50.186 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PBESaltFinder
//  INFO | 2020-09-10 10:59:50.613 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PBEInterationCountFinder
//  INFO | 2020-09-10 10:59:50.937 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PredictableSeedFinder
//  INFO | 2020-09-10 10:59:50.952 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: PredictableKeyStorePasswordFinder
//  INFO | 2020-09-10 10:59:50.972 | engine.JavaClassFileEntry (JavaClassFileEntry.java:26) | Checking the rule: HttpUrlFinder
//  INFO | 2020-09-10 10:59:51.107 | Interface.SubRunner (SubRunner.java:59) | Stopped the scanning process
//  INFO | 2020-09-10 10:59:51.109 | block.Default (Default.java:68) | Marshalling the Report from the Env. Info.
//  INFO | 2020-09-10 10:59:51.145 | Interface.SubRunner (SubRunner.java:62) | Writing the output to the file: /home/maister/Projects/cryptoguard/tmp/verySimple_klass_2.yaml
// /home/maister/Projects/cryptoguard/tmp/verySimple_klass_2.yaml
// ---
// projectName: "CryptoGuard"
// ProjectVersion: "04.05.01"
// Target:
//   RawCommand: "-in class -m Y -s /home/maister/Projects/cryptoguard/samples/VerySimple/very.class\
//     \ -X -android /InvalidPath/ -VV -n -java /home/maister/.sdkman/candidates/java/8.0.252.hs-adpt\
//     \ -o /home/maister/Projects/cryptoguard/tmp/verySimple_klass_2.yaml"
//   FullPath: "~/Projects/cryptoguard/UNKNOWN"
//   Type: "Class"
//   TargetSources:
//   - "/home/maister/Projects/cryptoguard/samples/VerySimple/very.class"
//   _PropertiesFilePath: "gradle.properties"
//   _ComputerOS: "Linux_5.4.0-47-generic"
//   _JVMVersion: "11.0.7+10"
//   _ProjectName: ""
// Issues:
// - Message: "Found: \"PBEWithMD5AndDES\""
//   Description: "Found broken crypto schemes"
//   RuleNumber: 1
//   RuleDesc: "Found broken crypto schemes"
//   CWEId: 256
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class"
//   _Id: "0"
// - Message: "Found: \"SHA1\""
//   Description: "Found broken hash functions"
//   RuleNumber: 2
//   RuleDesc: "Found broken hash functions"
//   CWEId: 759
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class"
//   _Id: "1"
// - Message: "Found: \"MD5\""
//   Description: "Found broken hash functions"
//   RuleNumber: 2
//   RuleDesc: "Found broken hash functions"
//   CWEId: 759
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class"
//   _Id: "2"
// - Message: "Found: Constant \"my+secret+key+lol\""
//   Description: "Used constant keys in code"
//   RuleNumber: 3
//   RuleDesc: "Used constant keys in code"
//   CWEId: 547
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class"
//   _Id: "3"
// - Message: "Found: Constant \"tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV\""
//   Description: "Used constant keys in code"
//   RuleNumber: 3
//   RuleDesc: "Used constant keys in code"
//   CWEId: 547
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class"
//   _Id: "4"
// - Message: "Found: Constant \"RandomInitVector\""
//   Description: "Used constant keys in code"
//   RuleNumber: 3
//   RuleDesc: "Used constant keys in code"
//   CWEId: 547
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class"
//   _Id: "5"
// - Message: "Found: \"RandomInitVector\""
//   Description: "Found constant IV in code"
//   RuleNumber: 10
//   RuleDesc: "Found constant IV in code"
//   CWEId: 547
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/VeryBadMain.class"
//   _Id: "6"
// - Message: "Found: \"tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV\""
//   Description: "Found constant salts in code"
//   RuleNumber: 9
//   RuleDesc: "Found constant salts in code"
//   CWEId: 547
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class"
//   _Id: "7"
// - Message: "Found: \"f77aLYLo\""
//   Description: "Found constant salts in code"
//   RuleNumber: 9
//   RuleDesc: "Found constant salts in code"
//   CWEId: 547
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class"
//   _Id: "8"
// - Message: "Found: \"17\""
//   Description: "Used < 1000 iteration for PBE"
//   RuleNumber: 8
//   RuleDesc: "Used < 1000 iteration for PBE"
//   CWEId: 326
//   Severity: "1"
//   _FullPath: "very.class/org/rigorityj/android_sample/crypto/PasswordUtils.class"
//   _Id: "9"
// _SchemaVersion: 3
// _DateTime: "2020-09-10_10:59:38"
// _UUID: "1dc888d7-767a-46f1-a38e-4108d1f4bf9e"
// Total Execution time: 12960 ms

// %% [markdown]
// ## Jar Setup

// %%
public static final String tempJarFile_xml = Utils.osPathJoin(testPath, "tempJarFile.xml");
public static final String tempJarFile_json = Utils.osPathJoin(testPath, "tempJarFile.json");

create(tempJarFile_xml);
create(tempJarFile_json);

public static final String jarOne = Utils.osPathJoin(testRec, "testable-jar", "build", "libs", "testable-jar.jar");
public static final String verySimple_Jar = Utils.osPathJoin(verySimple_Path, "very.jar");
public static final String srcOneGrvDep = Utils.osPathJoin(testRec, "testable-jar", "build", "dependencies");

// %% [markdown]
// ## JAR Tests

// %%
@RunWith(QuarantiningRunner.class)
@Quarantine({"com.binarytweed", "*"})
public class main_VerySimple_Scarf {
	public static void apply() {
	G.reset();
  String fileOut = tempJarFile_xml;

  new File(fileOut).delete();
  if (isLinux) {
    String args =
        makeArg(argsIdentifier.FORMAT, EngineType.JAR)
            + makeArg(argsIdentifier.SOURCE, verySimple_Jar)
            +
            // makeArg(argsIdentifier.DEPENDENCY, srcOneGrvDep) +
            makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML)
            + makeArg(argsIdentifier.OUT, fileOut)
            + makeArg(argsIdentifier.STREAM)
            + makeArg(argsIdentifier.ANDROID, "/InvalidPath/")
            + makeArg(argsIdentifier.JAVA, java_home)
            + makeArg(argsIdentifier.TIMEMEASURE)
            + makeArg(argsIdentifier.NOEXIT)
            + makeArg(argsIdentifier.PRETTY);

    try {
      EntryPoint.main(args.split(" "));

      AnalyzerReport report = AnalyzerReport.deserialize(new File(fileOut));
      assertFalse(report.getBugInstance().isEmpty());
      print(fileOut);
    } catch (Exception e) {
      e.printStackTrace();
      assertNull(e);
    }
  }
	}
}

// %%
start();
main_VerySimple_Scarf.apply();
end();
// Out:
//  INFO | 2020-09-10 10:59:51.540 | Interface.ArgumentsCheck (ArgumentsCheck.java:150) | Displaying info level logs
//  INFO | 2020-09-10 10:59:51.542 | Interface.ArgumentsCheck (ArgumentsCheck.java:178) | Using the output: ScarfXML
//  INFO | 2020-09-10 10:59:51.544 | Interface.ArgumentsCheck (ArgumentsCheck.java:343) | Scanning 1 source file(s).
//  INFO | 2020-09-10 10:59:51.546 | routing.EnvironmentInformation (EnvironmentInformation.java:376) | Building the Package Root Dir based on type
//  INFO | 2020-09-10 10:59:51.548 | routing.EnvironmentInformation (EnvironmentInformation.java:410) | Building the Root Directory
//  INFO | 2020-09-10 10:59:51.550 | stream.ScarfXML (ScarfXML.java:74) | Marshalling the header.
//  INFO | 2020-09-10 10:59:51.553 | Interface.SubRunner (SubRunner.java:57) | Starting the scanning process
//  INFO | 2020-09-10 10:59:51.554 | engine.JarEntry (JarEntry.java:25) | Checking the rule: InsecureAssymCryptoFinder
//  INFO | 2020-09-10 10:59:53.282 | engine.JarEntry (JarEntry.java:25) | Checking the rule: BrokenCryptoFinder
//  INFO | 2020-09-10 10:59:53.579 | engine.JarEntry (JarEntry.java:25) | Checking the rule: UntrustedPrngFinder
//  INFO | 2020-09-10 10:59:53.581 | engine.JarEntry (JarEntry.java:25) | Checking the rule: SSLSocketFactoryFinder
//  INFO | 2020-09-10 10:59:53.584 | engine.JarEntry (JarEntry.java:25) | Checking the rule: CustomTrustManagerFinder
//  INFO | 2020-09-10 10:59:53.586 | engine.JarEntry (JarEntry.java:25) | Checking the rule: HostNameVerifierFinder
//  INFO | 2020-09-10 10:59:53.587 | engine.JarEntry (JarEntry.java:25) | Checking the rule: BrokenHashFinder
//  INFO | 2020-09-10 10:59:53.671 | engine.JarEntry (JarEntry.java:25) | Checking the rule: ConstantKeyFinder
//  INFO | 2020-09-10 10:59:54.086 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PredictableIVFinder
//  INFO | 2020-09-10 10:59:54.159 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PBESaltFinder
//  INFO | 2020-09-10 10:59:54.494 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PBEInterationCountFinder
//  INFO | 2020-09-10 10:59:54.764 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PredictableSeedFinder
//  INFO | 2020-09-10 10:59:54.769 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PredictableKeyStorePasswordFinder
//  INFO | 2020-09-10 10:59:54.775 | engine.JarEntry (JarEntry.java:25) | Checking the rule: HttpUrlFinder
//  INFO | 2020-09-10 10:59:54.854 | Interface.SubRunner (SubRunner.java:59) | Stopped the scanning process
//  INFO | 2020-09-10 10:59:54.856 | stream.ScarfXML (ScarfXML.java:113) | Marshalling the bug category summary.
//  INFO | 2020-09-10 10:59:54.858 | Interface.SubRunner (SubRunner.java:62) | Writing the output to the file: /home/maister/Projects/cryptoguard/tmp/tempJarFile.xml
// /home/maister/Projects/cryptoguard/tmp/tempJarFile.xml
// <AnalyzerReport assessment_start_ts="2020-09-10_10:59:51" package_name="very" package_version="UNKNOWN" build_root_dir="/home/maister/Projects/cryptoguard/very.jar" package_root_dir="very.jar/" parser_fw="UNKNOWN" parser_fw_version="UNKNOWN" platform_name="Linux_5.4.0-47-generic" tool_name="Property Not Found" tool_version="Property Not Found" uuid="d08517be-ee9e-4454-be90-0b3070b52d3a"><BugInstance id="0">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>256</CweId>
//   <BugCode>BrokenCrypto</BugCode>
//   <BugMessage>Found: "PBEWithMD5AndDES". Found broken crypto schemes.</BugMessage>
// </BugInstance>
// <BugInstance id="1">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>759</CweId>
//   <BugCode>BrokenHash</BugCode>
//   <BugMessage>Found: "SHA1". Found broken hash functions.</BugMessage>
// </BugInstance>
// <BugInstance id="2">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>759</CweId>
//   <BugCode>BrokenHash</BugCode>
//   <BugMessage>Found: "MD5". Found broken hash functions.</BugMessage>
// </BugInstance>
// <BugInstance id="3">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantKey</BugCode>
//   <BugMessage>Found: Constant "my+secret+key+lol". Used constant keys in code.</BugMessage>
// </BugInstance>
// <BugInstance id="4">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//       <StartLine>78</StartLine>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantKey</BugCode>
//   <BugMessage>Found: Constant "tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV". Used constant keys in code.</BugMessage>
// </BugInstance>
// <BugInstance id="5">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantKey</BugCode>
//   <BugMessage>Found: Constant "RandomInitVector". Used constant keys in code.</BugMessage>
// </BugInstance>
// <BugInstance id="6">
//   <ClassName>org.rigorityj.android_sample.crypto.VeryBadMain</ClassName>
//   <Methods>
//     <Method id="0" primary="true">main</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantIV</BugCode>
//   <BugMessage>Found: "RandomInitVector". Found constant IV in code.</BugMessage>
// </BugInstance>
// <BugInstance id="7">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//       <StartLine>78</StartLine>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantSalt</BugCode>
//   <BugMessage>Found: "tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV". Found constant salts in code.</BugMessage>
// </BugInstance>
// <BugInstance id="8">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//       <StartLine>79</StartLine>
//     </Location>
//   </BugLocations>
//   <CweId>547</CweId>
//   <BugCode>ConstantSalt</BugCode>
//   <BugMessage>Found: "f77aLYLo". Found constant salts in code.</BugMessage>
// </BugInstance>
// <BugInstance id="9">
//   <ClassName>org.rigorityj.android_sample.crypto.PasswordUtils</ClassName>
//   <Methods>
//     <Method id="0" primary="true">init</Method>
//   </Methods>
//   <BugLocations>
//     <Location>
//       <SourceFile>very.jar/org/rigorityj/android_sample/crypto/PasswordUtils.class</SourceFile>
//     </Location>
//   </BugLocations>
//   <CweId>326</CweId>
//   <BugCode>PBE</BugCode>
//   <BugMessage>Found: "17". Used &lt; 1000 iteration for PBE.</BugMessage>
// </BugInstance>
// <BugSummary>
//   <BugCategory group="Found broken crypto schemes" code="1" count="1" bytes="0"/>
//   <BugCategory group="Found broken hash functions" code="2" count="2" bytes="0"/>
//   <BugCategory group="Used constant keys in code" code="3" count="3" bytes="0"/>
//   <BugCategory group="Used &lt; 1000 iteration for PBE" code="8" count="1" bytes="0"/>
//   <BugCategory group="Found constant salts in code" code="9" count="2" bytes="0"/>
//   <BugCategory group="Found constant IV in code" code="10" count="1" bytes="0"/>
// </BugSummary>
// </AnalyzerReport>
// <!--
// Analysis Timing (ms): 3304.
// -->
// Total Execution time: 3463 ms

// %%
@RunWith(QuarantiningRunner.class)
@Quarantine({"com.binarytweed", "*"})
public class main_TestableJar {
	public static void apply() {
	G.reset();
  String fileOut = tempJarFile_json;

  new File(fileOut).delete();
  if (isLinux) {
    String args =
        makeArg(argsIdentifier.FORMAT, EngineType.JAR)
            + makeArg(argsIdentifier.FORMATOUT, Listing.Default)
            + makeArg(argsIdentifier.SOURCE, jarOne)
            + makeArg(argsIdentifier.ANDROID, "/InvalidPath/")
            + makeArg(argsIdentifier.JAVA, java_home)
            + makeArg(argsIdentifier.DEPENDENCY, srcOneGrvDep)
            + makeArg(argsIdentifier.NOEXIT)
            + makeArg(argsIdentifier.OUT, fileOut);

    try {
      EntryPoint.main(args.split(" "));
      print(fileOut);
    } catch (Exception e) {
      e.printStackTrace();
      assertNull(e);
    }
  }
	}
}

// %%
start();
main_TestableJar.apply();
end();
// Out:
//  INFO | 2020-09-10 10:59:55.184 | Interface.ArgumentsCheck (ArgumentsCheck.java:150) | Displaying info level logs
//  INFO | 2020-09-10 10:59:55.186 | Interface.ArgumentsCheck (ArgumentsCheck.java:178) | Using the output: Default
//  INFO | 2020-09-10 10:59:55.187 | Interface.ArgumentsCheck (ArgumentsCheck.java:343) | Scanning 1 source file(s).
//  INFO | 2020-09-10 10:59:55.189 | routing.EnvironmentInformation (EnvironmentInformation.java:376) | Building the Package Root Dir based on type
//  INFO | 2020-09-10 10:59:55.190 | routing.EnvironmentInformation (EnvironmentInformation.java:410) | Building the Root Directory
//  INFO | 2020-09-10 10:59:55.195 | Interface.SubRunner (SubRunner.java:57) | Starting the scanning process
//  INFO | 2020-09-10 10:59:55.196 | engine.JarEntry (JarEntry.java:25) | Checking the rule: InsecureAssymCryptoFinder
//  INFO | 2020-09-10 11:00:03.650 | engine.JarEntry (JarEntry.java:25) | Checking the rule: BrokenCryptoFinder
//  INFO | 2020-09-10 11:00:04.139 | engine.JarEntry (JarEntry.java:25) | Checking the rule: UntrustedPrngFinder
//  INFO | 2020-09-10 11:00:04.443 | engine.JarEntry (JarEntry.java:25) | Checking the rule: SSLSocketFactoryFinder
//  INFO | 2020-09-10 11:00:05.023 | engine.JarEntry (JarEntry.java:25) | Checking the rule: CustomTrustManagerFinder
//  INFO | 2020-09-10 11:00:05.043 | engine.JarEntry (JarEntry.java:25) | Checking the rule: HostNameVerifierFinder
//  INFO | 2020-09-10 11:00:05.065 | engine.JarEntry (JarEntry.java:25) | Checking the rule: BrokenHashFinder
//  INFO | 2020-09-10 11:00:05.279 | engine.JarEntry (JarEntry.java:25) | Checking the rule: ConstantKeyFinder
//  INFO | 2020-09-10 11:00:05.898 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PredictableIVFinder
//  INFO | 2020-09-10 11:00:06.084 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PBESaltFinder
//  INFO | 2020-09-10 11:00:06.598 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PBEInterationCountFinder
//  INFO | 2020-09-10 11:00:07.024 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PredictableSeedFinder
//  INFO | 2020-09-10 11:00:07.155 | engine.JarEntry (JarEntry.java:25) | Checking the rule: PredictableKeyStorePasswordFinder
//  INFO | 2020-09-10 11:00:07.318 | engine.JarEntry (JarEntry.java:25) | Checking the rule: HttpUrlFinder
//  INFO | 2020-09-10 11:00:07.628 | Interface.SubRunner (SubRunner.java:59) | Stopped the scanning process
//  INFO | 2020-09-10 11:00:07.629 | block.Default (Default.java:68) | Marshalling the Report from the Env. Info.
//  INFO | 2020-09-10 11:00:07.631 | Interface.SubRunner (SubRunner.java:62) | Writing the output to the file: /home/maister/Projects/cryptoguard/tmp/tempJarFile.json
// /home/maister/Projects/cryptoguard/tmp/tempJarFile.json
// {"projectName":"CryptoGuard","ProjectVersion":"04.05.01","Target":{"RawCommand":"-in jar -m D -s /home/maister/Projects/cryptoguard/samples/testable-jar/build/libs/testable-jar.jar -android /InvalidPath/ -java /home/maister/.sdkman/candidates/java/8.0.252.hs-adpt -d /home/maister/Projects/cryptoguard/samples/testable-jar/build/dependencies -X -o /home/maister/Projects/cryptoguard/tmp/tempJarFile.json","FullPath":"testable-jar.jar/","Type":"JAR","TargetSources":["/home/maister/Projects/cryptoguard/samples/testable-jar/build/libs/testable-jar.jar"],"_PropertiesFilePath":"gradle.properties","_ComputerOS":"Linux_5.4.0-47-generic","_JVMVersion":"11.0.7+10","_ProjectName":"testable-jar"},"Issues":[{"Message":"Found: \"PBEWithMD5AndDES\"","Description":"Found broken crypto schemes","RuleNumber":1,"RuleDesc":"Found broken crypto schemes","CWEId":256,"Severity":"1","_FullPath":"testable-jar.jar/org/rigorityj/android_sample/crypto/PasswordUtils.class","_Id":"0"},{"Message":"Found: Untrused PRNG (java.util.Random)","Description":"Used untrusted PRNG","RuleNumber":13,"RuleDesc":"Used untrusted PRNG","CWEId":338,"Severity":"1","_FullPath":"testable-jar.jar/okhttp3/OkHttpClient.class","_Id":"1"},{"Message":"Should at least get One accepted Issuer from Other Sources in getAcceptedIssuers method of tester.Crypto","Description":"Uses untrusted TrustManager","RuleNumber":4,"RuleDesc":"Uses untrusted TrustManager","CWEId":349,"Severity":"1","_FullPath":"testable-jar.jar/tester/Crypto.class","_Id":"2"},{"Message":"Cause: Fixed \"[1]\"","Description":"Used untrusted HostNameVerifier","RuleNumber":6,"RuleDesc":"Used untrusted HostNameVerifier","CWEId":601,"Severity":"1","_FullPath":"testable-jar.jar/tester/Crypto.class","_Id":"3"},{"Message":"Cause: Fixed \"[0, 0]\"","Description":"Used untrusted HostNameVerifier","RuleNumber":6,"RuleDesc":"Used untrusted HostNameVerifier","CWEId":601,"Severity":"1","_FullPath":"testable-jar.jar/UNKNOWN.class","_Id":"4"},{"Message":"Found: \"SHA1\"","Description":"Found broken hash functions","RuleNumber":2,"RuleDesc":"Found broken hash functions","CWEId":759,"Severity":"1","_FullPath":"testable-jar.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"5"},{"Message":"Found: \"MD5\"","Description":"Found broken hash functions","RuleNumber":2,"RuleDesc":"Found broken hash functions","CWEId":759,"Severity":"1","_FullPath":"testable-jar.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"6"},{"Message":"Found: Constant \"my+secret+key+lol\"","Description":"Used constant keys in code","RuleNumber":3,"RuleDesc":"Used constant keys in code","CWEId":547,"Severity":"1","_FullPath":"testable-jar.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"7"},{"Message":"Found: Constant \"tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV\"","Description":"Used constant keys in code","RuleNumber":3,"RuleDesc":"Used constant keys in code","CWEId":547,"Severity":"1","_FullPath":"testable-jar.jar/org/rigorityj/android_sample/crypto/PasswordUtils.class","_Id":"8"},{"Message":"Found: Constant \"RandomInitVector\"","Description":"Used constant keys in code","RuleNumber":3,"RuleDesc":"Used constant keys in code","CWEId":547,"Severity":"1","_FullPath":"testable-jar.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"9"},{"Message":"Found: \"RandomInitVector\"","Description":"Found constant IV in code","RuleNumber":10,"RuleDesc":"Found constant IV in code","CWEId":547,"Severity":"1","_FullPath":"testable-jar.jar/org/rigorityj/android_sample/crypto/VeryBadMain.class","_Id":"10"},{"Message":"Found: \"tzL1AKl5uc4NKYaoQ4P3WLGIBFPXWPWdu1fRm9004jtQiV\"","Description":"Found constant salts in code","RuleNumber":9,"RuleDesc":"Found constant salts in code","CWEId":547,"Severity":"1","_FullPath":"testable-jar.jar/org/rigorityj/android_sample/crypto/PasswordUtils.class","_Id":"11"},{"Message":"Found: \"f77aLYLo\"","Description":"Found constant salts in code","RuleNumber":9,"RuleDesc":"Found constant sal ...
// Total Execution time: 12514 ms
